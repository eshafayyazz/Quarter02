# %% [markdown]
# <a href="https://colab.research.google.com/github/eshafayyazz/Quarter02/blob/main/Assignment03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=GEMINI_API_KEY)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import requests
from PIL import Image
from io import BytesIO
from IPython.display import display
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRmCy16nhIbV3pI1qLYHMJKwbH2458oiC9EmA&s'
response = requests.get(url)
img = Image.open(BytesIO(response.content))
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
prompt = """Describe the image in detail"""

# %%
response = model.generate_content([prompt, img])
print(response.text)
# Out:
# That's a striking close-up image!
#
#
# Here's a description:
#
# The photograph centers on a vibrant, small chameleon perched on a brightly colored flower. The chameleon is predominantly a brilliant, almost electric blue, with reddish-orange rings around its large, expressive eyes, which are golden-yellow with black pupils.  Its skin texture is slightly bumpy, and a tiny, pointed dewlap or throat pouch is visible. The chameleon's limbs are a similar shade of blue and appear to be gripping the petal.
#
# ...
